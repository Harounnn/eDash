# %% [markdown]
# # EDA (Exploratory Data Analysis)
# ***
# ## We have here a complex dataset (3 .csv files) which we have to deal with it carefully and extract only the data which will help us build our dashboard application .
# ***

# %%
#import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#options
# %matplotlib inline
pd.set_option('display.max_columns',None)

# %%
main_df = pd.read_csv('Stats.csv')
countries_df = pd.read_csv('StatsCountry.csv')
indicators_df = pd.read_csv('StatsSeries.csv')

main_df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975       1976  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 4  54.822121  54.894138  56.209438  57.267109  57.991138  59.36554  60.999962
#
#        1977      1978       1979       1980       1981       1982       1983  \
# 0       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 1       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 2       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 3       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 4  61.92268  62.69342  64.383186  65.617767  66.085152  66.608139  67.290451
#
#         1984       1985       1986      1987       1988       1989       1990  \
# 0        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN       NaN        NaN        NaN        NaN
# 4  68.510094  69.033211  69.944908  71.04187  71.693779  71.699097  71.995819
#
#         1991       1992       1993       1994      1995       1996       1997  \
# 0        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 4  72.602837  70.032722  70.464821  72.645683  71.81176  73.903511  74.425201
#
#         1998       1999       2000       2001       2002       2003  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  75.110817  76.254318  77.245682  78.800522  80.051399  80.805389
#
#         2004       2005       2006       2007       2008       2009  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  81.607063  82.489487  82.685509  83.280342  84.011871  84.195961
#
#         2010      2011       2012      2013       2014  2015  2016  2017  \
# 0        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 1        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 2        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 3        NaN       NaN        NaN       NaN        NaN   NaN   NaN   NaN
# 4  85.211998  85.24514  86.101669  85.51194  85.320152   NaN   NaN   NaN
#
#    2020  2025  2030  2035  2040  2045  2050  2055  2060  2065  2070  2075  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2080  2085  2090  2095  2100  Unnamed: 69
# 0   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN   NaN   NaN          NaN

# %%
countries_df.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
#                       Region          Income Group WB-2 code  \
# 0  Latin America & Caribbean  High income: nonOECD        AW
# 1                 South Asia            Low income        AF
# 2         Sub-Saharan Africa   Upper middle income        AO
# 3      Europe & Central Asia   Upper middle income        AL
# 4      Europe & Central Asia  High income: nonOECD        AD
#
#                          National accounts base year  \
# 0                                               2000
# 1                                            2002/03
# 2                                               2002
# 3  Original chained constant price data are resca...
# 4                                               1990
#
#    National accounts reference year                   SNA price valuation  \
# 0                               NaN     Value added at basic prices (VAB)
# 1                               NaN     Value added at basic prices (VAB)
# 2                               NaN  Value added at producer prices (VAP)
# 3                            1996.0     Value added at basic prices (VAB)
# 4                               NaN                                   NaN
#
#   Lending category Other groups  \
# 0              NaN          NaN
# 1              IDA         HIPC
# 2             IBRD          NaN
# 3             IBRD          NaN
# 4              NaN          NaN
#
#                          System of National Accounts  \
# 0  Country uses the 1993 System of National Accou...
# 1  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
# 3  Country uses the 1993 System of National Accou...
# 4  Country uses the 1968 System of National Accou...
#
#   Alternative conversion factor PPP survey year  \
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                       1991–96            2005
# 3                           NaN         Rolling
# 4                           NaN             NaN
#
#               Balance of Payments Manual in use  \
# 0  IMF Balance of Payments Manual, 6th edition.
# 1                                           NaN
# 2  IMF Balance of Payments Manual, 6th edition.
# 3  IMF Balance of Payments Manual, 6th edition.
# 4                                           NaN
#
#   External debt Reporting status       System of trade  \
# 0                            NaN  Special trade system
# 1                         Actual  General trade system
# 2                         Actual  Special trade system
# 3                         Actual  General trade system
# 4                            NaN  Special trade system
#
#      Government Accounting concept           IMF data dissemination standard  \
# 0                              NaN                                       NaN
# 1  Consolidated central government  General Data Dissemination System (GDDS)
# 2     Budgetary central government  General Data Dissemination System (GDDS)
# 3     Budgetary central government  General Data Dissemination System (GDDS)
# 4                              NaN                                       NaN
#
#                             Latest population census  \
# 0                                               2010
# 1                                               1979
# 2                                               1970
# 3                                               2011
# 4  2011. Population figures compiled from adminis...
#
#                              Latest household survey  \
# 0                                                NaN
# 1  Multiple Indicator Cluster Survey (MICS), 2010/11
# 2               Malaria Indicator Survey (MIS), 2011
# 3       Demographic and Health Survey (DHS), 2008/09
# 4                                                NaN
#
#    Source of most recent Income and expenditure data  \
# 0                                                NaN
# 1            Integrated household survey (IHS), 2008
# 2            Integrated household survey (IHS), 2008
# 3  Living Standards Measurement Study Survey (LSM...
# 4                                                NaN
#
#   Vital registration complete Latest agricultural census  \
# 0                         Yes                        NaN
# 1                         NaN                    2013/14
# 2                         NaN                       2015
# 3                         Yes                       2012
# 4                         Yes                        NaN
#
#    Latest industrial data  Latest trade data Latest water withdrawal data  \
# 0                     NaN             2012.0                          NaN
# 1                     NaN             2012.0                         2000
# 2                     NaN                NaN                         2005
# 3                  2010.0             2012.0                         2006
# 4                     NaN             2006.0                          NaN
#
#    Unnamed: 31
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
indicators_df.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# 0  Percentage of female population age 15-19 with...              NaN
# 1  Percentage of population age 15-19 with no edu...              NaN
# 2  Percentage of female population age 15+ with n...              NaN
# 3  Percentage of population age 15+ with no educa...              NaN
# 4  Percentage of female population age 20-24 with...              NaN
#
#   Periodicity Base Period Other notes Aggregation method  \
# 0         NaN         NaN         NaN                NaN
# 1         NaN         NaN         NaN                NaN
# 2         NaN         NaN         NaN                NaN
# 3         NaN         NaN         NaN                NaN
# 4         NaN         NaN         NaN                NaN
#
#   Limitations and exceptions  Notes from original source General comments  \
# 0                        NaN                         NaN              NaN
# 1                        NaN                         NaN              NaN
# 2                        NaN                         NaN              NaN
# 3                        NaN                         NaN              NaN
# 4                        NaN                         NaN              NaN
#
#                                               Source  \
# 0  Robert J. Barro and Jong-Wha Lee: http://www.b...
# 1  Robert J. Barro and Jong-Wha Lee: http://www.b...
# 2  Robert J. Barro and Jong-Wha Lee: http://www.b...
# 3  Robert J. Barro and Jong-Wha Lee: http://www.b...
# 4  Robert J. Barro and Jong-Wha Lee: http://www.b...
#
#   Statistical concept and methodology Development relevance  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
#
#   Related source links  Other web links  Related indicators  License Type  \
# 0                  NaN              NaN                 NaN           NaN
# 1                  NaN              NaN                 NaN           NaN
# 2                  NaN              NaN                 NaN           NaN
# 3                  NaN              NaN                 NaN           NaN
# 4                  NaN              NaN                 NaN           NaN
#
#    Unnamed: 20
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ***
# # Data Preprocessing
# ***

# %% [markdown]
# ***
# ## 1. Indicators dataframe
# ***

# %% [markdown]
# ***
# ## We will be interested in few indicators so our dataframe will be cleaner and will shrink
# ***

# %%
ed_ind = list()
for i in indicators_df['Topic']:
    if 'Education' in i:
        ed_ind.append(i)
ed_ind_arr = np.array(ed_ind)
ed_ind = list(np.unique(ed_ind_arr))

len(ed_ind)
# Out:
# 4

# %%
fltr = (indicators_df['Topic'] == ed_ind[0]) | (indicators_df['Topic'] == ed_ind[1]) | (indicators_df['Topic'] == ed_ind[2]) | (indicators_df['Topic'] == ed_ind[3])
print(indicators_df.shape)
new_indicators_df = indicators_df[fltr]
print(new_indicators_df.shape)
# Out:
# (3665, 21)
# (490, 21)

# %% [markdown]
# ***
# ## We will also get rid of the details (most of the columns)
# ***

# %%
new_indicators_df = new_indicators_df[['Topic','Indicator Name']]

# %%
new_indicators_df
# Out:
#                    Topic                                     Indicator Name
# 360   Education Equality         DHS: Gross attendance rate. Post Secondary
# 361   Education Equality  DHS: Gross attendance rate. Post Secondary. Fe...
# 362   Education Equality   DHS: Gross attendance rate. Post Secondary. Male
# 363   Education Equality  DHS: Gross attendance rate. Post Secondary. Qu...
# 364   Education Equality  DHS: Gross attendance rate. Post Secondary. Qu...
# ...                  ...                                                ...
# 3462  Education Equality  UIS: Rate of out-of-school adolescents of lowe...
# 3463  Education Equality  UIS: Rate of out-of-school adolescents of lowe...
# 3464  Education Equality  UIS: Rate of out-of-school adolescents of lowe...
# 3465  Education Equality  UIS: Rate of out-of-school adolescents of lowe...
# 3466  Education Equality  UIS: Rate of out-of-school adolescents of lowe...
#
# [490 rows x 2 columns]

# %%
new_indicators_df.isnull().sum()['Indicator Name']
# Out:
# 0

# %%
new_indicators_df.shape[0] - len(new_indicators_df['Indicator Name'].unique())
# Out:
# 0

# %% [markdown]
# ***
# ## The indicators dataframe is clean and good to go
# ***

# %% [markdown]
# ***
# ## 2. Countries dataframe
# ***

# %%
countries_df = countries_df[['Country Code','Short Name','Currency Unit','Region']]

print(countries_df.isnull().sum())

countries_df.dropna(inplace=True)

countries_df
# Out:
# Country Code      0
# Short Name        0
# Currency Unit    26
# Region           27
# dtype: int64
#     Country Code    Short Name       Currency Unit                      Region
# 0            ABW         Aruba       Aruban florin   Latin America & Caribbean
# 1            AFG   Afghanistan      Afghan afghani                  South Asia
# 2            AGO        Angola      Angolan kwanza          Sub-Saharan Africa
# 3            ALB       Albania        Albanian lek       Europe & Central Asia
# 4            AND       Andorra                Euro       Europe & Central Asia
# ..           ...           ...                 ...                         ...
# 236          XKX        Kosovo                Euro       Europe & Central Asia
# 237          YEM         Yemen         Yemeni rial  Middle East & North Africa
# 238          ZAF  South Africa  South African rand          Sub-Saharan Africa
# 239          ZMB        Zambia  New Zambian kwacha          Sub-Saharan Africa
# 240          ZWE      Zimbabwe         U.S. dollar          Sub-Saharan Africa
#
# [214 rows x 4 columns]

# %%
print(f"Number of rows : {countries_df.shape[0]}")
print('------------------------------------------------------------------')

for col in countries_df.columns:
    print(f"Number of unique values in the {col} column is {len(countries_df[col].unique())}")
# Out:
# Number of rows : 214
# ------------------------------------------------------------------
# Number of unique values in the Country Code column is 214
# Number of unique values in the Short Name column is 214
# Number of unique values in the Currency Unit column is 151
# Number of unique values in the Region column is 7

# %% [markdown]
# ***
# ## Now the countries dataframe seems reasonable and good to go
# ***

# %% [markdown]
# ***
# ## 3. Main dataframe
# ***

# %%
main_df = main_df.loc[:,:'2020']
main_df.isnull().sum()[['Country Name','Country Code','Indicator Name']]
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# dtype: int64

# %%
#Indicators present in our dataframe
len(main_df['Indicator Name'].unique())
# Out:
# 3665

# %% [markdown]
# ***
# ## We want only indicators related to our topics saved previously in a list called 'ed_ind' when we used that list to shrink the indicators dataframe , so we will use that dataframe to shrink our main dataframe
# ***

# %%
df = main_df.merge(new_indicators_df,left_on='Indicator Name', right_on='Indicator Name', how='left')
df.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
# 5   Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 6  Adjusted net enrolment rate, primary, gender p...  UIS.NERA.1.GPI
# 7     Adjusted net enrolment rate, primary, male (%)  SE.PRM.TENR.MA
# 8  Adjusted net enrolment rate, upper secondary, ...      UIS.NERA.3
# 9  Adjusted net enrolment rate, upper secondary, ...    UIS.NERA.3.F
#
#         1970       1971       1972       1973       1974       1975  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  54.822121  54.894138  56.209438  57.267109  57.991138  59
971  1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  \
# 114747   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  \
# 114747   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  \
# 114747   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# 114747   NaN   NaN   NaN  54.0   NaN   NaN   NaN  25.0  26.0   NaN  30.0
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         2015  2016  2017  2020                      Topic
# 114747   NaN   NaN   NaN   NaN  Early Childhood Education
# 275997   NaN   NaN   NaN   NaN  Early Childhood Education
# 275996   NaN   NaN   NaN   NaN  Early Childhood Education
# 378616   NaN   NaN   NaN   NaN  Early Childhood Education
# 378617   NaN   NaN   NaN   NaN  Early Childhood Education
# 378618   NaN   NaN   NaN   NaN  Early Childhood Education
# 378619   NaN   NaN   NaN   NaN  Early Childhood Education
# 378620   NaN   NaN   NaN   NaN  Early Childhood Education
# 378621   NaN   NaN   NaN   NaN  Early Childhood Education
# 378622   NaN   NaN   NaN   NaN  Early Childhood Education

# %%
#chaging the position of the topic column
cols = list(df.columns)
topic_str_index = cols.index('Topic')
if topic_str_index != 1:
    topic_str = cols[topic_str_index]
    cols.remove(topic_str)
    cols.insert(1,topic_str)
    df = df[cols]
df.head(10)
# Out:
#        Country Code                      Topic  \
# 114747          ATG  Early Childhood Education
# 275997          CUW  Early Childhood Education
# 275996          CUW  Early Childhood Education
# 378616          GUM  Early Childhood Education
# 378617          GUM  Early Childhood Education
# 378618          GUM  Early Childhood Education
# 378619          GUM  Early Childhood Education
# 378620          GUM  Early Childhood Education
# 378621          GUM  Early Childhood Education
# 378622          GUM  Early Childhood Education
#
#                                            Indicator Name  1970  1971  1972  \
# 114747  Enrolment in early childhood educational devel...   NaN   NaN   NaN
# 275997  Enrolment in early childhood education, female...   NaN   NaN   NaN
# 275996  Enrolment in early childhood education, both s...   NaN   NaN   NaN
# 378616  Enrolment in early childhood education, both s...   NaN   NaN   NaN
# 378617  Enrolment in early childhood education, female...   NaN   NaN   NaN
# 378618  Enrolment in early childhood education, privat...   NaN   NaN   NaN
# 378619  Enrolment in early childhood education, privat...   NaN   NaN   NaN
# 378620  Enrolment in early childhood education, public...   NaN   NaN   NaN
# 378621  Enrolment in early childhood education, public...   NaN   NaN   NaN
# 378622  Enrolment in early childhood educational devel...   NaN   NaN   NaN
#
#         1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  \
# 114747   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  \
# 114747   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  \
# 114747   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 114747   NaN  54.0   NaN   NaN   NaN  25.0  26.0   NaN  30.0   NaN   NaN
# 275997   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 275996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378616   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378618   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378619   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378620   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378621   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 378622   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         2017  2020
# 114747   NaN   NaN
# 275997   NaN   NaN
# 275996   NaN   NaN
# 378616   NaN   NaN
# 378617   NaN   NaN
# 378618   NaN   NaN
# 378619   NaN   NaN
# 378620   NaN   NaN
# 378621   NaN   NaN
# 378622   NaN   NaN

# %% [markdown]
# ***
# ## At this point , we came with a new dataframe which is really our main dataframe for this project
# ***

# %% [markdown]
# # . . .
